# %%
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
from keras_preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

from math import nan
from keras.layers import LSTM, Embedding, Dense, TimeDistributed, Dropout, Bidirectional, Attention
import keras
import tensorflow as tf
# from keras_contrib.layers import CRF
from keras import Model, Input
import matplotlib.pyplot as plt
from tensorflow.python.keras.layers import SpatialDropout1D
import nltk
from nltk.stem import WordNetLemmatizer

from time import sleep
from tqdm import tqdm

# %%
def preprocess_dataset(dataset_name, word_column, sentence_column, tag_column, other_tag):
    data = pd.read_csv(dataset_name, encoding="latin1")
    data = data.fillna(method="ffill")

    # words = list(set(data["Word"].values))
    words = list(set(data[word_column].values))
    words.append("ENDPAD")
    num_words = len(words)

    tags = list(set(data[tag_column].values))
    num_tags = len(tags)

    class SentenceGetter(object):
        def __init__(self, data):
            self.n_sent = 1
            self.data = data
            self.empty = False
            agg_func = lambda s: [(w, t) for w, t in zip(s[word_column].values.tolist(), s[tag_column].values.tolist())]
            self.grouped = self.data.groupby(sentence_column).apply(agg_func)
            self.sentences = [s for s in self.grouped]

        def get_next(self):
            try:
                s = self.grouped["Sentence {}".format(self.n_sent)]
                self.n_sent += 1
                return s
            except:
                return None

    getter = SentenceGetter(data)
    sentences = getter.sentences

    word2idx = {w: i for i, w in enumerate(words)}
    tag2idx = {t: i for i, t in enumerate(tags)}

    max_len = data.groupby([sentence_column], sort=False).size().max()

    x = [[word2idx[w[0]] for w in s] for s in sentences]
    x = pad_sequences(maxlen=max_len, sequences=x, padding="post", value=word2idx["ENDPAD"])

    y = [[tag2idx[w[1]] for w in s] for s in sentences]
    y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx[other_tag])

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

    return x_train, x_test, y_train, y_test, word2idx, tag2idx, max_len, words, tags

# %%
def build_matrix_embeddings(path, num_tokens, embedding_dim, word_index):


    hits, misses = 0, 0
    embeddings_index = {}

    print('Loading file...')

    sleep(0.5)

    for line in tqdm(open(path, encoding='utf-8')):
        word, coefs = line.split(maxsplit=1)
        embeddings_index[word] = np.fromstring(coefs, "f", sep=" ")

    print("Processed %s Word Vectors." % len(embeddings_index))

    sleep(0.5)

    # Prepare embedding matrix
    embedding_matrix = np.zeros((num_tokens, embedding_dim))

    for word, i in tqdm(word_index.items()):
        if i >= num_tokens:
            continue
        try:
            embedding_vector = embeddings_index.get(word)
            if embedding_vector is not None:
                embedding_matrix[i] = embedding_vector
                hits += 1
            else:
                embedding_vector = embeddings_index.get(str(word).lower())
                if embedding_vector is not None:
                    embedding_matrix[i] = embedding_vector
                    hits += 1
                else:
                    embedding_vector = embeddings_index.get(str(word).upper())
                    if embedding_vector is not None:
                        embedding_matrix[i] = embedding_vector
                        hits += 1
                misses += 1
        except:
            embedding_matrix[i] = embeddings_index.get('UNK')

    print("Hits: %d Tokens | Miss: %d Tokens" % (hits, misses))

    return embedding_matrix

# %%
dataset = 'kaggle/input/covid_subset_0.5perc.csv'
#dataset = 'kaggle/input/ner_dataset.csv'
x_train, x_test, y_train, y_test, word2idx, tag2idx, max_len, words, tags = preprocess_dataset(dataset, 'word', 'sentence', 'entity', 'Other')

# %%
file_path = 'kaggle/embed/glove.6B.100d.txt'

glove_embeddings = \
build_matrix_embeddings(path=file_path,
                        num_tokens=len(words), 
                        embedding_dim=100,
                        word_index=word2idx)
# Out:
# Loading file...
# 400000it [00:08, 49199.55it/s]
# Processed 400000 Word Vectors.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 27637/27637 [00:00<00:00, 811108.71it/s]
# Hits: 13412 Tokens | Miss: 14225 Tokens

# %%
print('Tensorflow version:', tf.__version__)
print('GPU detected:', tf.config.list_physical_devices('GPU'))

idx2tag = {v: k for k, v in tag2idx.items()}
idx2word = {i: w for w, i in word2idx.items()}

input_word = Input(shape=(max_len,))
#model = Embedding(input_dim=len(words), output_dim=128, input_length=max_len)(input_word)
model = Embedding(input_dim=glove_embeddings.shape[0], output_dim=glove_embeddings.shape[1],\
                  weights=[glove_embeddings], trainable=True)(input_word)
model = SpatialDropout1D(0.2)(model)
rnn = Bidirectional(LSTM(units=128, return_sequences=True, recurrent_dropout=0.1))(model)
# attention = Attention()([rnn, rnn])
# hidden1 = keras.layers.Dense(len(tags), activation='relu')(attention)
# hidden2 = keras.layers.Dense(len(tags), activation='relu')(hidden1)
out = TimeDistributed(Dense(len(tags), activation="softmax"))(rnn)
model = Model(input_word, out)
model.summary()

model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

history = model.fit(
    x=x_train,
    y=y_train,
    validation_data=(x_test, y_test),
    batch_size=32,
    epochs=3,
    verbose=1
)

model.evaluate(x_test, y_test)
# Out:
# Tensorflow version: 2.10.1
# GPU detected: []
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 512)]             0
#
#  embedding (Embedding)       (None, 512, 100)          2763700
#
#  tf.identity (TFOpLambda)    (None, 512, 100)          0
#
#  bidirectional (Bidirectiona  (None, 512, 256)         234496
#  l)
#
#  time_distributed (TimeDistr  (None, 512, 117)         30069
#  ibuted)
#
# =================================================================
# Total params: 3,028,265
# Trainable params: 3,028,265
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/3
# 25/25 [==============================] - 23s 854ms/step - loss: 2.0116 - accuracy: 0.7794 - val_loss: 1.1181 - val_accuracy: 0.8108
# Epoch 2/3
# 25/25 [==============================] - 21s 847ms/step - loss: 1.0038 - accuracy: 0.8247 - val_loss: 1.0154 - val_accuracy: 0.8108
# Epoch 3/3
# 25/25 [==============================] - 21s 843ms/step - loss: 0.9081 - accuracy: 0.8262 - val_loss: 0.9166 - val_accuracy: 0.8162
# 7/7 [==============================] - 1s 128ms/step - loss: 0.9166 - accuracy: 0.8162
# [0.9166202545166016, 0.8162207007408142]

# %%
i = np.random.randint(0, x_train.shape[0])
# i = 151
print(i)
p = model.predict(np.array([x_train[i]]))
p = np.argmax(p, axis=-1)
y_true = y_train[i]
print("{:15}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-" * 30)
for w, true, pred in zip(x_train[i], y_true, p[0]):
    if w == len(words) - 1:
        break
    print("{:15}{}\t{}".format(words[w], tags[true], tags[pred]))
print("----------------------------")
# Out:
# 679
# 1/1 [==============================] - 0s 275ms/step
# Word           True 	 Pred
#
# ------------------------------
# first          B-ORDINAL	Other
# case           Other	Other
# of             Other	Other
# coronavirus    B-CORONAVIRUS	B-CORONAVIRUS
# disease        Other	Other
# 2019           B-DATE	Other
# covid-19       B-CORONAVIRUS	Other
# pneumonia      B-DISEASE_OR_SYNDROME	Other
# in             Other	Other
# taiwan         B-GPE	Other
# an             Other	Other
# outbreak       Other	Other
# of             Other	Other
# respiratory    B-CHEMICAL	Other
# illness        I-CHEMICAL	Other
# proved         Other	Other
# to             Other	Other
# be             Other	Other
# infected       Other	Other
# by             Other	Other
# a              Other	Other
# 2019           B-DATE	Other
# novel          Other	Other
# coronavirus    B-CORONAVIRUS	B-CORONAVIRUS
# officially     Other	Other
# named          Other	Other
# coronavirus    B-CORONAVIRUS	B-CORONAVIRUS
# disease        Other	Other
# 2019           B-DATE	Other
# covid-19       B-CORONAVIRUS	Other
# ,              Other	Other
# was            Other	Other
# notified       Other	Other
# first          B-ORDINAL	Other
# in             Other	Other
# wuhan          B-GPE	Other
# china          B-CELL	Other
# and            Other	Other
# has            Other	Other
# spread         Other	Other
# rapidly        Other	Other
# in             Other	Other
# china          B-CELL	Other
# and            Other	Other
# to             Other	Other
# other          Other	Other
# parts          Other	Other
# of             Other	Other
# the            Other	Other
# world.         Other	Other
# herein         B-ORG	Other
# we             Other	Other
# reported       Other	Other
# the            Other	Other
# first          B-ORDINAL	Other
# confirmed      Other	Other
# case           Other	Other
# of             Other	Other
# novel          Other	Other
# coronavirus    B-CORONAVIRUS	B-CORONAVIRUS
# pneumonia      B-DISEASE_OR_SYNDROME	Other
# ncp            B-ORGANISM	Other
# imported       Other	Other
# from           Other	Other
# china          B-CELL	Other
# in             Other	Other
# taiwan         B-GPE	Other
# this           Other	Other
# case           Other	Other
# report         Other	Other
# revealed       Other	Other
# a              Other	Other
# natural        Other	Other
# course         Other	Other
# of             Other	Other
# ncp            B-ORGANISM	Other
# with           Other	Other
# self-recovery, Other	Other
# which          Other	Other
# may            Other	Other
# be             Other	Other
# a              Other	Other
# good           Other	Other
# example        Other	Other
# in             Other	Other
# comparison     Other	Other
# with           Other	Other
# medical        Other	Other
# treatments     B-THERAPEUTIC_OR_PREVENTIVE_PROCEDURE	Other
# on             Other	Other
# december       B-DATE	Other
# 31,            I-DATE	Other
# 2019           I-DATE	Other
# an             Other	Other
# outbreak       Other	Other
# of             Other	Other
# respiratory    B-CHEMICAL	Other
# illness        I-CHEMICAL	Other
# later          Other	Other
# proved         Other	Other
# to             Other	Other
# be             Other	Other
# caused         Other	Other
# by             Other	Other
# a              Other	Other
# novel          Other	Other
# coronavirus    B-CORONAVIRUS	B-CORONAVIRUS
# officially     Other	Other
# named          Other	Other
# coronavirus    B-CORONAVIRUS	B-CORONAVIRUS
# disease        Other	Other
# 2019           B-DATE	Other
# covid-19       B-CORONAVIRUS	Other
# ,              Other	Other
# was            Other	Other
# notified       Other	Other
# first          B-ORDINAL	Other
# in             Other	Other
# wuhan          B-GPE	Other
# a              Other	Other
# city           Other	Other
# of             Other	Other
# hubei          B-GPE	Other
# province       I-GPE	Other
# people's       B-ORGANISM	Other
# republic       I-ORGANISM	Other
# of             Other	Other
# china          B-CELL	Other
# prc            B-GPE	Other
# .              Other	Other
# covid-19       B-CORONAVIRUS	Other
# rapidly        Other	Other
# spreads        Other	Other
# in             Other	Other
# china          B-CELL	Other
# and            Other	Other
# to             Other	Other
# other          Other	Other
# parts          Other	Other
# of             Other	Other
# the            Other	Other
# world.         Other	Other
# currently      Other	Other
# more           Other	Other
# than           Other	Other
# 70,000         Other	Other
# laboratory-confirmedB-GENE_OR_GENOME	Other
# cases          I-GENE_OR_GENOME	Other
# in             Other	Other
# china          B-CELL	Other
# have           Other	Other
# been           Other	Other
# reported,      Other	Other
# and            Other	Other
# the            Other	Other
# case           B-CHEMICAL	Other
# count          I-CHEMICAL	Other
# has            Other	Other
# been           Other	Other
# rising         Other	Other
# daily          B-DATE	Other
# some           Other	Other
# travelersrelatedOther	Other
# transmission   Other	Other
# were           Other	Other
# also           Other	Other
# identified     Other	Other
# in             Other	Other
# many           Other	Other
# countries,     Other	Other
# including      Other	Other
# taiwan         B-GPE	Other
# singapore      B-GPE	Other
# vietnam        B-GPE	Other
# republic       Other	Other
# of             Other	Other
# korea          B-CHEMICAL	Other
# malaysia       B-CHEMICAL	Other
# thailand       B-GPE	Other
# japan          B-GPE	Other
# germany        B-GPE	Other
# france         B-GPE	Other
# united         Other	Other
# states         Other	Other
# (u.s.),        Other	Other
# australia      B-GPE	Other
# etc.           Other	Other
# through        Other	Other
# an             Other	Other
# international  Other	Other
# conveyance,    Other	Other
# and            Other	Other
# raised         Other	Other
# a              Other	Other
# global         B-CHEMICAL	Other
# health         I-CHEMICAL	Other
# emergency.     Other	Other
# 1              Other	Other
# as             Other	Other
# of             Other	Other
# february       B-DATE	Other
# 18,            I-DATE	Other
# 2020           I-DATE	Other
# there          Other	Other
# were           Other	Other
# 22             Other	Other
# confirmed      B-GENE_OR_GENOME	Other
# cases          I-GENE_OR_GENOME	Other
# in             Other	Other
# taiwan         B-GPE	Other
# herein         B-ORG	Other
# we             Other	Other
# presented      Other	Other
# the            Other	Other
# first          B-ORDINAL	Other
# case           Other	Other
# identified     Other	Other
# in             Other	Other
# taiwan         B-GPE	Other
# on             Other	Other
# january        B-DATE	Other
# 21,            I-DATE	Other
# 2020           I-DATE	Other
# on             Other	Other
# january        B-DATE	Other
# 20,            I-DATE	Other
# 2020           I-DATE	Other
# a              Other	Other
# 55-year-old    B-DATE	Other
# woman          B-ORGANISM	Other
# who            Other	Other
# worked         Other	Other
# in             Other	Other
# wuhan          B-GPE	Other
# china          B-CELL	Other
# arrived        Other	Other
# at             Other	Other
# taiwan         B-ORG	Other
# taoyuan        I-ORG	Other
# international  I-ORG	Other
# airport        I-ORG	Other
# and            Other	Other
# presented      Other	Other
# to             Other	Other
# quarantine     B-THERAPEUTIC_OR_PREVENTIVE_PROCEDURE	Other
# officials      Other	Other
# immediately,   Other	Other
# with           Other	Other
# a              Other	Other
# history        Other	Other
# of             Other	Other
# sore           B-CHEMICAL	Other
# throat         I-CHEMICAL	Other
# dry            B-ORG	Other
# cough          I-ORG	Other
# fatigue        B-DISEASE_OR_SYNDROME	Other
# and            Other	Other
# lowgrade       B-DISEASE_OR_SYNDROME	Other
# subjective     Other	Other
# fever          Other	Other
# since          Other	Other
# january        B-DATE	Other
# 11,            I-DATE	Other
# 2020           I-DATE	Other
# owing          Other	Other
# to             Other	Other
# the            Other	Other
# outbreak       Other	Other
# of             Other	Other
# covid-19       B-CORONAVIRUS	Other
# in             Other	Other
# wuhan          B-GPE	Other
# city           I-GPE	Other
# and            Other	Other
# the            Other	Other
# announcement   Other	Other
# of             Other	Other
# related        Other	Other
# symptoms       B-SIGN_OR_SYMPTOM	Other
# she            Other	Other
# was            Other	Other
# immediately    Other	Other
# placed         Other	Other
# in             Other	Other
# quarantine     B-THERAPEUTIC_OR_PREVENTIVE_PROCEDURE	Other
# ward           B-GROUP	Other
# and            Other	Other
# underwent      Other	Other
# examination.   Other	Other
# although       Other	Other
# the            Other	Other
# patient        B-ORGANISM	Other
# denied         Other	Other
# spending       Other	Other
# time           Other	Other
# at             Other	Other
# the            Other	Other
# huanan         B-CHEMICAL	Other
# seafood        I-CHEMICAL	Other
# wholesale      I-CHEMICAL	Other
# market         I-CHEMICAL	Other
# and            Other	Other
# reported       Other	Other
# no             Other	Other
# known          Other	Other
# contact        Other	Other
# with           Other	Other
# ill            Other	Other
# people         B-ORGANISM	Other
# during         Other	Other
# her            B-ORGANISM	Other
# stay           Other	Other
# in             Other	Other
# wuhan          B-GPE	Other
# specimens      B-DISEASE_OR_SYNDROME	Other
# including      Other	Other
# oropharyngeal  B-GENE_OR_GENOME	Other
# swab           I-GENE_OR_GENOME	Other
# and            Other	Other
# sputum         B-SUBSTRATE	Other
# were           Other	Other
# collected      Other	Other
# for            Other	Other
# severe         B-CORONAVIRUS	Other
# acute          I-CORONAVIRUS	Other
# respiratory    I-CORONAVIRUS	B-DISEASE_OR_SYNDROME
# syndrome       I-CORONAVIRUS	Other
# coronavirus    I-CORONAVIRUS	B-CORONAVIRUS
# 2              Other	Other
# sars-cov-2     B-CORONAVIRUS	Other
# real-time      Other	Other
# reverse-transcriptaseB-GENE_OR_GENOME	Other
# polymerase-chain-reactionOther	Other
# (rrt-pcr)      Other	Other
# in             Other	Other
# accordance     Other	Other
# with           Other	Other
# the            Other	Other
# taiwan         Other	Other
# centers        B-CHEMICAL	Other
# for            I-CHEMICAL	Other
# disease        I-CHEMICAL	Other
# control        I-CHEMICAL	Other
# tcdc           B-CHEMICAL	Other
# guidance       B-THERAPEUTIC_OR_PREVENTIVE_PROCEDURE	Other
# apart          Other	Other
# from           Other	Other
# a              Other	Other
# history        Other	Other
# of             Other	Other
# hypothyroidism B-DISEASE_OR_SYNDROME	Other
# with           Other	Other
# regular        Other	Other
# medical        Other	Other
# follow-up,     Other	Other
# she            Other	Other
# had            Other	Other
# no             Other	Other
# other          Other	Other
# underlying     B-GENE_OR_GENOME	Other
# disease        I-GENE_OR_GENOME	Other
# before         Other	Other
# this           Other	Other
# onset.         Other	Other
# according      Other	Other
# to             Other	Other
# the            Other	Other
# records        Other	Other
# of             Other	Other
# quarantine     B-THERAPEUTIC_OR_PREVENTIVE_PROCEDURE	Other
# officials,     Other	Other
# the            Other	Other
# vital          Other	Other
# sign           Other	Other
# of             Other	Other
# the            Other	Other
# patient        B-ORGANISM	Other
# showed         Other	Other
# body           B-GENE_OR_GENOME	Other
# temperature    I-GENE_OR_GENOME	Other
# bt             B-CHEMICAL	Other
# of             Other	Other
# 38.0           Other	Other
# c              B-GENE_OR_GENOME	Other
# and            Other	Other
# oxygen         B-LABORATORY_PROCEDURE	Other
# saturation     I-LABORATORY_PROCEDURE	Other
# (spo2)         Other	Other
# of             Other	Other
# 88e90          B-CHEMICAL	Other
# under          Other	Other
# ambient        Other	Other
# air            B-MATERIAL	Other
# before         Other	Other
# seeking        Other	Other
# medical        Other	Other
# treatment      Other	Other
# in             Other	Other
# taiwan         B-GPE	Other
# she            Other	Other
# bought         Other	Other
# over-the-counterB-CHEMICAL	Other
# medicine       Other	Other
# to             Other	Other
# release        Other	Other
# the            Other	Other
# symptoms       B-SIGN_OR_SYMPTOM	Other
# after          Other	Other
# admission      Other	Other
# to             Other	Other
# our            Other	Other
# hospital,      Other	Other
# her            Other	Other
# vital          B-CHEMICAL	Other
# signs          I-CHEMICAL	Other
# remained       Other	Other
# stable,        Other	Other
# apart          Other	Other
# from           Other	Other
# the            Other	Other
# exertional     B-DISEASE_OR_SYNDROME	Other
# dyspnea        I-DISEASE_OR_SYNDROME	Other
# intermittent   Other	Other
# dry            B-ORG	Other
# cough          I-ORG	Other
# and            Other	Other
# sore           B-CHEMICAL	Other
# throat         I-CHEMICAL	Other
# fig            B-DISEASE_OR_SYNDROME	Other
# 1)             Other	Other
# .              Other	Other
# the            Other	Other
# initial        Other	Other
# physical       Other	Other
# examination    Other	Other
# revealed       Other	Other
# a              Other	Other
# bt             Other	Other
# of             Other	Other
# 36.4           Other	Other
# c,             Other	Other
# blood          B-TISSUE	Other
# pressure       I-TISSUE	Other
# of             Other	Other
# 93/53          Other	Other
# mm             B-GENE_OR_GENOME	Other
# hg             I-GENE_OR_GENOME	Other
# pulse          Other	Other
# of             Other	Other
# 87             Other	Other
# bpm,           Other	Other
# respiratory    Other	Other
# rate           Other	Other
# of             Other	Other
# 20             B-QUANTITY	Other
# breath/min     I-QUANTITY	Other
# and            Other	Other
# spo2           Other	Other
# of             Other	Other
# 91%            Other	Other
# while          Other	Other
# the            Other	Other
# patient        B-ORGANISM	Other
# was            Other	Other
# breathing      Other	Other
# supplement     Other	Other
# oxygen         B-CHEMICAL	Other
# by             Other	Other
# nasal          B-CHEMICAL	Other
# cannula        I-CHEMICAL	Other
# at             I-CHEMICAL	Other
# 3              I-CHEMICAL	Other
# l              I-CHEMICAL	Other
# min.           Other	Other
# the            Other	Other
# breathing      Other	Other
# sound          Other	Other
# was            Other	Other
# normal         Other	Other
# initially.     Other	Other
# the            Other	Other
# laboratory     Other	Other
# results        Other	Other
# reflected      Other	Other
# lymphopenia    B-DISEASE_OR_SYNDROME	Other
# 531            B-CARDINAL	Other
# cells          B-CELL	Other
# ul),           Other	Other
# and            Other	Other
# elevated       Other	Other
# aspartate      B-CHEMICAL	Other
# aminotransferaseOther	Other
# (ast,          Other	Other
# 78             Other	Other
# u/l            B-GPE	Other
# ,              Other	Other
# alanine        B-CHEMICAL	Other
# aminotransferaseOther	Other
# (alt,          Other	Other
# 41             Other	Other
# u/l),          Other	Other
# c-reactive     B-GENE_OR_GENOME	Other
# protein        I-GENE_OR_GENOME	Other
# crp            B-GENE_OR_GENOME	Other
# 7.8            B-QUANTITY	Other
# mg             I-QUANTITY	Other
# l),            Other	Other
# and            Other	Other
# lactate        B-GENE_OR_GENOME	Other
# dehydrogenase  I-GENE_OR_GENOME	Other
# ldh            B-GENE_OR_GENOME	Other
# 295            B-GENE_OR_GENOME	Other
# ----------------------------

# %%
i = 65
print(i)
p = model.predict(np.array([x_train[i]]))
# Out:
# 65
# 1/1 [==============================] - 0s 46ms/step

# %%
p[0][7]
# Out:
# array([1.0149045e-03, 4.9902797e-02, 2.8836224e-04, 1.0499849e-03,
#        6.2999665e-04, 7.2337146e-04, 3.7516817e-04, 1.4316953e-03,
#        1.4341905e-03, 1.5450266e-04, 3.1493750e-04, 2.4996619e-04,
#        7.3772838e-04, 3.3050840e-04, 1.0587914e-03, 6.7634846e-04,
#        1.7188586e-03, 6.9928134e-04, 4.5405333e-03, 5.7481008e-04,
#        2.8238422e-04, 4.9291463e-03, 8.9148022e-03, 1.9839773e-04,
#        3.2986901e-04, 3.9629903e-02, 6.2550191e-04, 4.1925260e-03,
#        2.7366157e-04, 3.6528232e-04, 7.8856869e-04, 3.8730475e-04,
#        1.0111126e-03, 5.6302984e-04, 2.4939733e-04, 1.6066578e-03,
#        9.4540743e-03, 6.9909199e-04, 4.7315713e-02, 3.4822110e-04,
#        3.0291028e-04, 8.9252442e-03, 2.3532055e-02, 1.2037166e-02,
#        2.4140051e-03, 5.0438003e-04, 4.1516149e-01, 2.3991968e-04,
#        3.9364002e-03, 2.8326095e-03, 2.0275955e-04, 2.8856448e-04,
#        4.6837382e-04, 5.4264455e-03, 1.1171360e-02, 3.4942050e-04,
#        1.0920324e-03, 1.2438878e-03, 1.8678027e-03, 5.1643222e-04,
#        1.0940421e-03, 3.3328397e-04, 3.2576860e-03, 4.1750702e-04,
#        1.9958485e-03, 4.1405653e-04, 1.8681964e-04, 7.7180559e-04,
#        2.3428197e-03, 5.0812028e-03, 1.1354956e-02, 1.8104813e-04,
#        3.0463660e-04, 5.6400441e-04, 5.3334129e-03, 4.9274357e-04,
#        4.3259375e-04, 1.0230431e-03, 1.1897962e-02, 5.7980064e-03,
#        5.7870767e-04, 5.1050810e-03, 5.3086388e-04, 4.8471719e-04,
#        3.9913866e-04, 7.1441097e-04, 7.0181611e-04, 8.6724723e-04,
#        3.9663899e-04, 1.6057033e-02, 3.6014360e-04, 7.0809334e-04,
#        4.4673902e-04, 2.2267102e-04, 5.7783082e-02, 4.1156958e-04,
#        8.9106433e-02, 2.4270752e-04, 2.5071166e-03, 3.0471666e-03,
#        3.0475226e-04, 7.0988172e-04, 1.7946986e-03, 3.0479397e-04,
#        4.2294804e-04, 1.2286536e-02, 8.7937177e-04, 1.9459071e-02,
#        3.2303052e-04, 2.6587583e-04, 2.8481539e-03, 1.1244328e-03,
#        5.2853336e-04, 4.1285746e-02, 5.5917166e-04, 1.9889511e-04,
#        1.7053157e-04], dtype=float32)

# %%
print([(idx2word[w], idx2tag[t]) for w, t in zip(x_test[107], y_test[107])])
# Out:
# [('patients', 'B-GROUP'), ('particularly', 'Other'), ('those', 'Other'), ('with', 'Other'), ('severe', 'B-ORG'), ('symptoms', 'I-ORG'), ('as', 'Other'), ('the', 'Other'), ('clinical', 'Other'), ('effects', 'Other'), ('might', 'Other'), ('be', 'Other'), ('related', 'Other'), ('to', 'Other'), ('the', 'Other'), ('indication', 'Other'), ('(severities', 'Other'), ('of', 'Other'), ('illness', 'B-DISEASE_OR_SYNDROME'), (',', 'Other'), ('the', 'Other'), ('timing', 'Other'), ('of', 'Other'), ('intervention,', 'Other'), ('the', 'Other'), ('dose', 'Other'), ('and', 'Other'), ('duration', 'Other'), ('of', 'Other'), ('corticosteroids', 'B-CHEMICAL'), ('therapy', 'Other'), ('9', 'Other'), ('.', 'Other'), ('of', 'Other'), ('note,', 'Other'), ('as', 'Other'), ('documented', 'Other'), ('in', 'Other'), ('a', 'Other'), ('series', 'Other'), ('of', 'Other'), ('randomized', 'Other'), ('clinical', 'Other'), ('trials', 'Other'), ('(rct),', 'Other'), ('low', 'Other'), ('or', 'Other'), ('physiologic', 'Other'), ('dose', 'Other'), ('of', 'Other'), ('corticosteroids', 'B-CHEMICAL'), ('treatment', 'Other'), ('did', 'Other'), ('not', 'Other'), ('reduce', 'Other'), ('mortality', 'Other'), ('from', 'Other'), ('septic', 'B-GENE_OR_GENOME'), ('shock', 'I-GENE_OR_GENOME'), ('caused', 'Other'), ('by', 'Other'), ('primary', 'B-DISEASE_OR_SYNDROME'), ('lung', 'I-DISEASE_OR_SYNDROME'), ('infections', 'I-DISEASE_OR_SYNDROME'), ('but', 'Other'), ('it', 'Other'), ('could', 'Other'), ('bring', 'Other'), ('clinical', 'B-GENE_OR_GENOME'), ('benefits', 'I-GENE_OR_GENOME'), ('to', 'Other'), ('secondary', 'Other'), ('outcomes,', 'Other'), ('such', 'Other'), ('as', 'Other'), ('earlier', 'Other'), ('reversal', 'Other'), ('of', 'Other'), ('shock', 'B-DISEASE_OR_SYNDROME'), ('shorter', 'Other'), ('duration', 'Other'), ('to', 'Other'), ('exit', 'Other'), ('from', 'Other'), ('icu', 'Other'), ('and', 'Other'), ('mechanical', 'B-THERAPEUTIC_OR_PREVENTIVE_PROCEDURE'), ('ventilation', 'I-THERAPEUTIC_OR_PREVENTIVE_PROCEDURE'), ('9,', 'Other'), ('10', 'B-DATE'), ('.', 'Other'), ('besides,', 'Other'), ('salvage', 'B-THERAPEUTIC_OR_PREVENTIVE_PROCEDURE'), ('corticosteroids', 'B-CHEMICAL'), ('treatment', 'Other'), ('for', 'Other'), ('severe', 'Other'), ('patients', 'B-GROUP'), ('with', 'Other'), ('advanced', 'Other'), ('ards', 'B-DISEASE_OR_SYNDROME'), ('could', 'Other'), ('alleviate', 'Other'), ('the', 'Other'), ('pulmonary', 'B-DISEASE_OR_SYNDROME'), ('fibrosis', 'I-DISEASE_OR_SYNDROME'), ('and', 'Other'), ('prevent', 'Other'), ('progressive', 'Other'), ('pathological', 'Other'), ('deterioration', 'Other'), ('11', 'Other'), (',', 'Other'), ('which', 'Other'), ('provides', 'Other'), ('a', 'Other'), ('good', 'Other'), ('framework', 'Other'), ('for', 'Other'), ('explaining', 'Other'), ('why', 'Other'), ('some', 'Other'), ('critical', 'Other'), ('patients', 'B-GROUP'), ('with', 'Other'), ('sars', 'B-CORONAVIRUS'), ('infection', 'Other'), ('benefit', 'Other'), ('from', 'Other'), ('rescue', 'Other'), ('corticosteroids', 'B-CHEMICAL'), ('therapy.', 'Other'), ('more', 'Other'), ('importantly,', 'Other'), ('mortality', 'Other'), ('benefit', 'Other'), ('favored', 'Other'), ('the', 'Other'), ('severe', 'Other'), ('hin1-illness', 'B-DISEASE_OR_SYNDROME'), ('in', 'Other'), ('the', 'Other'), ('adjunctive', 'B-ORG'), ('treatment', 'I-ORG'), ('group', 'Other'), ('with', 'Other'), ('low', 'B-GENE_OR_GENOME'), ('dose', 'I-GENE_OR_GENOME'), ('of', 'Other'), ('corticosteroids', 'B-CHEMICAL'), ('12', 'Other'), ('.', 'Other'), ('evidently,', 'Other'), ('all', 'Other'), ('these', 'Other'), ('results', 'Other'), ('strongly', 'B-CELL_COMPONENT'), ('suggest', 'I-CELL_COMPONENT'), ('that', 'Other'), ('proper', 'Other'), ('use', 'Other'), ('of', 'Other'), ('low-dose', 'B-CELL'), ('corticosteroids', 'I-CELL'), ('may', 'Other'), ('bring', 'Other'), ('survival', 'Other'), ('advantages', 'Other'), ('for', 'Other'), ('critically', 'Other'), ('ill', 'Other'), ('patients', 'B-GROUP'), ('with', 'Other'), ('2019-ncov', 'B- ...
